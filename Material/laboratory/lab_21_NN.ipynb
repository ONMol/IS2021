# %% [markdown]
# # <center>Лабораторная работа №21</center>
#
# **Тема:** . Разработка, отладка и испытание программ, взаимодействующих с отдельными элементами массива
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, взаимодействующих с отдельными элементами массива.
#
# **Материал:** [Лекция 6.1  Библиотека NumPy. Массивы библиотеки NumPy](../../material/lectures/lect06_01.ipynb)
