# %% [markdown]
# ## <center>Лабораторная работа №17</center>
#
# **Тема:** Разработка, отладка и испытание программ по созданию изображений
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, обрабатывающих изображения.
#
# **Материал:** [Лекция 4.1  Создание и загрузка изображения, получение информации об изображении](../../material/lectures/lect04_01.ipynb)

# %% [markdown]
# **<center>Задания:</center>**
#
# **Выполните примеры из лекции.** См.
# [**Лекция 4_1. Создание и загрузка изображения, получение информации об изображении**](material/lectures/lect04_01.ipynb)
#
# Скопируйте примеры в соответствующие ячейки и добейтесь правильной работы, с использование собственных изображений.

# %% [markdown]
# **Пример 1** Открыть изображение и отобразить его на экране через внешнюю программу.

# %% [markdown]
# **Пример 2** Обрезать картинку с через Image.crop().

# %% [markdown]
# **Пример 3** Поворнуть изображения через rotate().

# %% [markdown]
# **Пример 4** Нарисовать прямоугольник, сохранить в файл.

# %% [markdown]
# **Пример 5** Добавить текст внутрь нарисованного прямоугольника, сохранить результат в файл.
