# %% [markdown]
# ## <center>Лабораторная работа №27</center>
#
# **Тема:** Разработка, отладка и испытание программ взаимодействующих с объектами библиотеки Pandas
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, использующих библиотеку Pandas для выполнения простейших операций над DataFrame.
#
# **Материал:** [Лекция 6.3  Лекция 6_3. Библиотека Pandas](../../material/lectures/lect06_03.ipynb)

# %% [markdown]
# ### <center>Содержание работы</center>
#
# 1) Изучите материал лекции и выполните примеры, приведенные в ней.
# 2) Самостоятельно создайте и сохраните файл формата csv согласно варианта задания, заполнив его не менее 10 записями (все примеры лекции находятся в папке /lectures/Files/PandasFolder).
#
# 3) Выполните действия над указанным данными, считанными из файла (прокомментируйте полученный результат).
